# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimage

image = pltimage.imread('.\\6_26.jpg')

plt.subplot(221)
plt.imshow(image[:,:,0])
plt.subplot(222)
plt.imshow(image[:,:,1])
plt.subplot(223)
plt.imshow(image[:,:,2])
plt.subplot(224)
plt.imshow(image)

plt.show()

# basic operations

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimage

image = pltimage.imread('.\\6_26.jpg')

plt.subplot(121)
plt.imshow(image[200:600,810:1235])

plt.subplot(122)
plt.imshow(image)
plt.show()

# show cat's head separately

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimage

image = pltimage.imread('.\\6_26.jpg')

plt.subplot(221)
plt.imshow(image[200:600,810:1235])

plt.subplot(222)
plt.imshow(image)

theHead = image[200:600,810:1235]
compositeImage = image

for i in range(200,600):
    for j in range(1235,1660):
        for k in range(0,3):
            compositeImage[i,j,k] = theHead[i-200,j-1235,k]

plt.subplot(223)
plt.imshow(compositeImage)
plt.show()

# add cat' head somewhere else on the image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as pltimage

from PIL import Image
im = Image.open("6_26.jpg")
im2 = Image.open("6_26_head.jpg")

# here i tried to use PIL library to swap RGB channels, but it didn't work
# 'failed' code is below


# import PIL as pillowtest
# image = pltimage.imread('.\\6_26.jpg')

# PIL.Image.alpha_composite(im2, im)
# im2 = im[200:400,800:1200]
# im.rotate(45).show()
# PIL.ImageColor.getrgb(im[128,67])

# image2 = pillowtest
# image.ImageColor.getrgb()

# b, g, r = image.split()
# im = Image.merge("RGB", (r, g, b))
