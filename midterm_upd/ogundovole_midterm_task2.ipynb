# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import matplotlib.image as img
from scipy import ndimage

from skimage import io
from skimage import feature
from skimage.data import data_dir
from skimage.util import img_as_ubyte
from skimage.morphology import disk
from skimage.morphology import erosion, skeletonize, dilation, opening, closing

original_image = img.imread('image1.png')

# obtaining histogram:
image_histogram = plt.hist(original_image.ravel())

# implementing gray world:
def rgb2gray(original):
    return np.dot(original[...,:3], [0.299, 0.587, 0.114])

image_gray = rgb2gray(original_image)

# linear stretching of brightness:
# original_image = np.mean(original_image, -1)
# rows, cols = original_image.shape

# for i in range(0, rows-1):
#     for j in range(0, cols-1):
#         stretched_image[i, j] = original_image[i, j] + 20

# rows, cols = original_image.shape

stretched_image = original_image + 20

fig = plt.figure(figsize = (20, 15))
plt.subplot(221), plt.imshow(original_image)
plt.title('Original Image')
plt.subplot(222), plt.imshow(image_gray, cmap = 'gray')
plt.title('Gray World')
plt.subplot(223), plt.imshow(stretched_image)
plt.title('Stretched Image')

plt.show()
