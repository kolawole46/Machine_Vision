# %%
# Task: apply canny filter for Lena
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img

import os
from scipy import ndimage as ndi
from skimage import io
from skimage import feature
from skimage.data import data_dir
from skimage.util import img_as_ubyte
from skimage.morphology import disk
from skimage.morphology import erosion, skeletonize, dilation, opening, closing

# Compute the Canny filter for two values of sigma
im2 = img.imread('lena_cover.jpg')
# im = im.squeeze()
imLena = np.mean(im2, -1)

edges1 = feature.canny(imLena, sigma = 7)
edges2 = feature.canny(imLena, sigma = 16)

# display results for Lena image
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 3), sharex=True, sharey=True)

ax1.imshow(imLena, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('Lena', fontsize=20)

ax2.imshow(edges1, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title('Canny filter, $\sigma=7$', fontsize=20)

ax3.imshow(edges2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Canny filter, $\sigma=16$', fontsize=20)

fig.tight_layout()

plt.show()

# %%
# Task: apply canny filter for Cameraman

# Compute the Canny filter for two values of sigma
imCamera = img.imread('cameraman.jpg')

edges3 = feature.canny(imCamera, sigma = 3)
edges4 = feature.canny(imCamera, sigma = 6)

# display results for Lena image
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 3), sharex=True, sharey=True)

ax1.imshow(imCamera, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('Cameraman', fontsize=20)

ax2.imshow(edges3, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title('Canny filter, $\sigma=3$', fontsize=20)

ax3.imshow(edges4, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Canny filter, $\sigma=6$', fontsize=20)

fig.tight_layout()

plt.show()

# %%
# Task: Cameraman binarization

image = img.imread('cameraman.jpg')
# image = img.imread('lena_cover.jpg')
# image = data.camera()
tt = np.median(image)
binary = image > tt

fig, axes = plt.subplots(ncols = 2, figsize = (15, 10))
ax = axes.ravel()

ax[0].imshow(image, cmap = plt.cm.gray)
ax[0].set_title('Original Cameraman')

ax[1].imshow(binary, cmap = plt.cm.gray)
ax[1].set_title('Result')

for a in ax:
    a.axis('off')

plt.show()

# %%
# Task: Skeletonize the Cameraman

cameraman = io.imread(os.path.join(data_dir, "cameraman.jpg"), as_grey=True)
selem = disk(6)
sk = skeletonize(cameraman == 0)
plot_comparison(cameraman, sk, 'skeletonize')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-f85867e16e62> in <module>()
#       4 selem = disk(6)
#       5 sk = skeletonize(cameraman == 0)
# ----> 6 plot_comparison(cameraman, sk, 'skeletonize')
#
# NameError: name 'plot_comparison' is not defined
